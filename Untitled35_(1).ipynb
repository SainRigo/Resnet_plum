# %% [markdown]
# <a href="https://colab.research.google.com/github/SainRigo/Resnet_plum/blob/main/Untitled35_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import os


# we access the file where are store our images

print(os.listdir("/content/drive/MyDrive/plum_data/plum_data/"))
# Out:
# ['Good', 'Bad']

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, AveragePooling2D
from tensorflow.keras.layers import Concatenate , Flatten , Dense , Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121 , VGG16
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import normalize
from tensorflow.keras.optimizers import Adam

# %%
defective_path_l = os.listdir('/content/drive/MyDrive/plum_data/plum_data/Bad/')
good_path_l = os.listdir('/content/drive/MyDrive/plum_data/plum_data/Good/')
len(defective_path_l)+ len(good_path_l)
# Out:
# 4507

# %%
Image_data = []        # in this list will be append all the images read
Labels_image = []      # in this list will be append the label (statu) in the same oder of each image


# here is the path to the infected images.
# we used a for loop with a step 2 to just read half of the images.

defective_path = "/content/drive/MyDrive/plum_data/plum_data/Bad/"
defective_path_l.sort()

for i in range(0, len(defective_path_l), 2):
    image_path = os.path.join(defective_path, defective_path_l[i])
    images_pil = cv2.imread(image_path)
    image_array = Image.fromarray(images_pil , 'RGB')                     # read of image as RGB
    resize_img = image_array.resize((224 , 224))                          # resizing of image
    Image_data.append(np.array(resize_img))
    Labels_image.append(1)                                                # label on the image


# here we look for the total number of images read and the number of labels in our list
len(Image_data), len(Labels_image)
# Out:
# (1877, 1877)

# %%
good_path = "/content/drive/MyDrive/plum_data/plum_data/Good/"
good_path_l.sort()

for j in range(0, len(good_path_l), 2):
    image_pathu = os.path.join(good_path, good_path_l[j])
    images_pilu = cv2.imread(image_pathu)
    image_arrayu = Image.fromarray(images_pilu, 'RGB')
    resize_imgu = image_arrayu.resize((224 , 224))
    Image_data.append(np.array(resize_imgu))
    Labels_image.append(0)

# we labeled the uninfected cells as 0


# here is the total images for the study
len(Image_data), len(Labels_image)
# Out:
# (2254, 2254)

# %%
cells = np.array(Image_data)
labels = np.array(Labels_image)

# %%
print('Shape of Cells : {} , shape of labels : {}'.format(cells.shape , labels.shape))
# Out:
# Shape of Cells : (2254, 224, 224, 3) , shape of labels : (2254,)

# %%
plt.figure(1 , figsize = (15 , 9))
n = 0
for i in range(8):
    n += 1
    r = np.random.randint(0 , cells.shape[0] , 1)
    plt.subplot(4 , 4 , n)
    plt.subplots_adjust(hspace = 0.56, wspace = 0.56)
    plt.imshow(cells[r[0]])
    plt.title('{} : {}'.format('defective fruit image' if labels[r[0]] == 1 else 'good fruit image' ,
                               labels[r[0]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
n = np.arange(cells.shape[0])
np.random.shuffle(n)
cells = cells[n]
labels = labels[n]

# %%
cells = cells.astype(np.float32)/255.00
labels = labels.astype(np.int32)

# %%
# we split the data into train, test and validation set

from sklearn.model_selection import train_test_split

train_x , X , train_y , Y = train_test_split(cells , labels, test_size = 0.3 , random_state = 111)

test_x, valid_x, test_y, valid_y = train_test_split(X,Y, test_size = 0.5, random_state= 111)

# %%
print('Proportion of the data:')
print("train set: X_train: {}, Y_train: {}".format(train_x.shape, train_y.shape))
print('%===============================================%')
print('Validation set: x_validation: {}, y_validation: {}'.format(valid_x.shape, valid_y.shape))
print('%===============================================%')
print("test shape: x_test: {}, y_test: {}".format(test_x.shape, test_y.shape))
# Out:
# Proportion of the data:
# train set: X_train: (1577, 224, 224, 3), Y_train: (1577,)
# %===============================================%
# Validation set: x_validation: (339, 224, 224, 3), y_validation: (339,)
# %===============================================%
# test shape: x_test: (338, 224, 224, 3), y_test: (338,)

# %%
plt.figure(1 , figsize = (15 ,5))
n = 0
for z , j in zip([train_y , valid_y,  test_y] , ['train labels','validation labels', 'test labels']):
    n += 1
    plt.subplot(1 , 3  , n)
    sns.countplot(x = z )
    plt.title(j)
plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import *


def resnet(input_shape, n_classes):

  def conv_bn_rl(x, f, k=1, s=1, p='same'):
    x = Conv2D(f, k, strides=s, padding=p)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    return x


  def identity_block(tensor, f):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    x = Add()([x, tensor])
    output = ReLU()(x)
    return output


  def conv_block(tensor, f, s):
    x = conv_bn_rl(tensor, f)
    x = conv_bn_rl(x, f, 3, s)
    x = Conv2D(4*f, 1)(x)
    x = BatchNormalization()(x)

    shortcut = Conv2D(4*f, 1, strides=s)(tensor)
    shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    output = ReLU()(x)
    return output


  def resnet_block(x, f, r, s=2):
    x = conv_block(x, f, s)
    for _ in range(r-1):
      x = identity_block(x, f)
    return x


  input = Input(input_shape)

  x = conv_bn_rl(input, 64, 7, 2)
  x = MaxPool2D(3, strides=2, padding='same')(x)

  x = resnet_block(x, 64, 3, 1)
  x = resnet_block(x, 128, 4)
  x = resnet_block(x, 256, 6)
  x = resnet_block(x, 512, 3)

  x = GlobalAvgPool2D()(x)

  output = Dense(n_classes, activation='softmax')(x)

  model = Model(input, output)
  return model

n_classes = 2  # Replace with the actual number of classes in your classification problem

# Create the model instance using the resnet function
input_shape=(224, 224, 3)
model = resnet(input_shape, n_classes)

# Compile the model
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.01),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_53 (Conv2D)          (None, 112, 112, 64)         9472      ['input_2[0][0]']
#
#  batch_normalization_53 (Ba  (None, 112, 112, 64)         256       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 112, 112, 64)         0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)           0         ['re_lu_49[0][0]']
#  g2D)
#
#  conv2d_54 (Conv2D)          (None, 56, 56, 64)           4160      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_54 (Ba  (None, 56, 56, 64)           256       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 56, 56, 64)           36928     ['re_lu_50[0][0]']
#
#  batch_normalization_55 (Ba  (None, 56, 56, 64)           256       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 56, 56, 256)          16640     ['re_lu_51[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 56, 56, 256)          16640     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_56 (Ba  (None, 56, 56, 256)          1024      ['conv2d_56[0][0]']
#  tchNormalization)
#
#  batch_normalization_57 (Ba  (None, 56, 56, 256)          1024      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_56[0][0]
#                                                                     ',
#                                                                      'batch_normalization_57[0][0]
#                                                                     ']
#
#  re_lu_52 (ReLU)             (None, 56, 56, 256)          0         ['add_16[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 56, 56, 64)           16448     ['re_lu_52[0][0]']
#
#  batch_normalization_58 (Ba  (None, 56, 56, 64)           256       ['conv2d_58[0][0]']
#  tchNormalization)
#
#  re_lu_53 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  conv2d_59 (Conv2D)          (None, 56, 56, 64)           36928     ['re_lu_53[0][0]']
#
#  batch_normalization_59 (Ba  (None, 56, 56, 64)           256       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 56, 56, 256)          16640     ['re_lu_54[0][0]']
#
#  batch_normalization_60 (Ba  (None, 56, 56, 256)          1024      ['conv2d_60[0][0]']
#  tchNormalization)
#
#  add_17 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_60[0][0]
#                                                                     ',
#                                                                      're_lu_52[0][0]']
#
#  re_lu_55 (ReLU)             (None, 56, 56, 256)          0         ['add_17[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 56, 56, 64)           16448     ['re_lu_55[0][0]']
#
#  batch_normalization_61 (Ba  (None, 56, 56, 64)           256       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  re_lu_56 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  conv2d_62 (Conv2D)          (None, 56, 56, 64)           36928     ['re_lu_56[0][0]']
#
#  batch_normalization_62 (Ba  (None, 56, 56, 64)           256       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  re_lu_57 (ReLU)             (None, 56, 56, 64)           0         ['batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_63 (Conv2D)          (None, 56, 56, 256)          16640     ['re_lu_57[0][0]']
#
#  batch_normalization_63 (Ba  (None, 56, 56, 256)          1024      ['conv2d_63[0][0]']
#  tchNormalization)
#
#  add_18 (Add)                (None, 56, 56, 256)          0         ['batch_normalization_63[0][0]
#                                                                     ',
#                                                                      're_lu_55[0][0]']
#
#  re_lu_58 (ReLU)             (None, 56, 56, 256)          0         ['add_18[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 56, 56, 128)          32896     ['re_lu_58[0][0]']
#
#  batch_normalization_64 (Ba  (None, 56, 56, 128)          512       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  re_lu_59 (ReLU)             (None, 56, 56, 128)          0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_59[0][0]']
#
#  batch_normalization_65 (Ba  (None, 28, 28, 128)          512       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  re_lu_60 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_66 (Conv2D)          (None, 28, 28, 512)          66048     ['re_lu_60[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 28, 28, 512)          131584    ['re_lu_58[0][0]']
#
#  batch_normalization_66 (Ba  (None, 28, 28, 512)          2048      ['conv2d_66[0][0]']
#  tchNormalization)
#
#  batch_normalization_67 (Ba  (None, 28, 28, 512)          2048      ['conv2d_67[0][0]']
#  tchNormalization)
#
#  add_19 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_66[0][0]
#                                                                     ',
#                                                                      'batch_normalization_67[0][0]
#                                                                     ']
#
#  re_lu_61 (ReLU)             (None, 28, 28, 512)          0         ['add_19[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 28, 28, 128)          65664     ['re_lu_61[0][0]']
#
#  batch_normalization_68 (Ba  (None, 28, 28, 128)          512       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  re_lu_62 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  conv2d_69 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_62[0][0]']
#
#  batch_normalization_69 (Ba  (None, 28, 28, 128)          512       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  re_lu_63 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  conv2d_70 (Conv2D)          (None, 28, 28, 512)          66048     ['re_lu_63[0][0]']
#
#  batch_normalization_70 (Ba  (None, 28, 28, 512)          2048      ['conv2d_70[0][0]']
#  tchNormalization)
#
#  add_20 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_70[0][0]
#                                                                     ',
#                                                                      're_lu_61[0][0]']
#
#  re_lu_64 (ReLU)             (None, 28, 28, 512)          0         ['add_20[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 28, 28, 128)          65664     ['re_lu_64[0][0]']
#
#  batch_normalization_71 (Ba  (None, 28, 28, 128)          512       ['conv2d_71[0][0]']
#  tchNormalization)
#
#  re_lu_65 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_72 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_65[0][0]']
#
#  batch_normalization_72 (Ba  (None, 28, 28, 128)          512       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  re_lu_66 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  conv2d_73 (Conv2D)          (None, 28, 28, 512)          66048     ['re_lu_66[0][0]']
#
#  batch_normalization_73 (Ba  (None, 28, 28, 512)          2048      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  add_21 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_73[0][0]
#                                                                     ',
#                                                                      're_lu_64[0][0]']
#
#  re_lu_67 (ReLU)             (None, 28, 28, 512)          0         ['add_21[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 28, 28, 128)          65664     ['re_lu_67[0][0]']
#
#  batch_normalization_74 (Ba  (None, 28, 28, 128)          512       ['conv2d_74[0][0]']
#  tchNormalization)
#
#  re_lu_68 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  conv2d_75 (Conv2D)          (None, 28, 28, 128)          147584    ['re_lu_68[0][0]']
#
#  batch_normalization_75 (Ba  (None, 28, 28, 128)          512       ['conv2d_75[0][0]']
#  tchNormalization)
#
#  re_lu_69 (ReLU)             (None, 28, 28, 128)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  conv2d_76 (Conv2D)          (None, 28, 28, 512)          66048     ['re_lu_69[0][0]']
#
#  batch_normalization_76 (Ba  (None, 28, 28, 512)          2048      ['conv2d_76[0][0]']
#  tchNormalization)
#
#  add_22 (Add)                (None, 28, 28, 512)          0         ['batch_normalization_76[0][0]
#                                                                     ',
#                                                                      're_lu_67[0][0]']
#
#  re_lu_70 (ReLU)             (None, 28, 28, 512)          0         ['add_22[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 28, 28, 256)          131328    ['re_lu_70[0][0]']
#
#  batch_normalization_77 (Ba  (None, 28, 28, 256)          1024      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  re_lu_71 (ReLU)             (None, 28, 28, 256)          0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_71[0][0]']
#
#  batch_normalization_78 (Ba  (None, 14, 14, 256)          1024      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  re_lu_72 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  conv2d_79 (Conv2D)          (None, 14, 14, 1024)         263168    ['re_lu_72[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 14, 14, 1024)         525312    ['re_lu_70[0][0]']
#
#  batch_normalization_79 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_80 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_80[0][0]']
#  tchNormalization)
#
#  add_23 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_79[0][0]
#                                                                     ',
#                                                                      'batch_normalization_80[0][0]
#                                                                     ']
#
#  re_lu_73 (ReLU)             (None, 14, 14, 1024)         0         ['add_23[0][0]']
#
#  conv2d_81 (Conv2D)          (None, 14, 14, 256)          262400    ['re_lu_73[0][0]']
#
#  batch_normalization_81 (Ba  (None, 14, 14, 256)          1024      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  re_lu_74 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_82 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_74[0][0]']
#
#  batch_normalization_82 (Ba  (None, 14, 14, 256)          1024      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  re_lu_75 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  conv2d_83 (Conv2D)          (None, 14, 14, 1024)         263168    ['re_lu_75[0][0]']
#
#  batch_normalization_83 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  add_24 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_83[0][0]
#                                                                     ',
#                                                                      're_lu_73[0][0]']
#
#  re_lu_76 (ReLU)             (None, 14, 14, 1024)         0         ['add_24[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 14, 14, 256)          262400    ['re_lu_76[0][0]']
#
#  batch_normalization_84 (Ba  (None, 14, 14, 256)          1024      ['conv2d_84[0][0]']
#  tchNormalization)
#
#  re_lu_77 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_77[0][0]']
#
#  batch_normalization_85 (Ba  (None, 14, 14, 256)          1024      ['conv2d_85[0][0]']
#  tchNormalization)
#
#  re_lu_78 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 14, 14, 1024)         263168    ['re_lu_78[0][0]']
#
#  batch_normalization_86 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  add_25 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_86[0][0]
#                                                                     ',
#                                                                      're_lu_76[0][0]']
#
#  re_lu_79 (ReLU)             (None, 14, 14, 1024)         0         ['add_25[0][0]']
#
#  conv2d_87 (Conv2D)          (None, 14, 14, 256)          262400    ['re_lu_79[0][0]']
#
#  batch_normalization_87 (Ba  (None, 14, 14, 256)          1024      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  re_lu_80 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  conv2d_88 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_80[0][0]']
#
#  batch_normalization_88 (Ba  (None, 14, 14, 256)          1024      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  re_lu_81 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 14, 14, 1024)         263168    ['re_lu_81[0][0]']
#
#  batch_normalization_89 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  add_26 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_89[0][0]
#                                                                     ',
#                                                                      're_lu_79[0][0]']
#
#  re_lu_82 (ReLU)             (None, 14, 14, 1024)         0         ['add_26[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 14, 14, 256)          262400    ['re_lu_82[0][0]']
#
#  batch_normalization_90 (Ba  (None, 14, 14, 256)          1024      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  re_lu_83 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_91 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_83[0][0]']
#
#  batch_normalization_91 (Ba  (None, 14, 14, 256)          1024      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  re_lu_84 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  conv2d_92 (Conv2D)          (None, 14, 14, 1024)         263168    ['re_lu_84[0][0]']
#
#  batch_normalization_92 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  add_27 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_92[0][0]
#                                                                     ',
#                                                                      're_lu_82[0][0]']
#
#  re_lu_85 (ReLU)             (None, 14, 14, 1024)         0         ['add_27[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 14, 14, 256)          262400    ['re_lu_85[0][0]']
#
#  batch_normalization_93 (Ba  (None, 14, 14, 256)          1024      ['conv2d_93[0][0]']
#  tchNormalization)
#
#  re_lu_86 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  conv2d_94 (Conv2D)          (None, 14, 14, 256)          590080    ['re_lu_86[0][0]']
#
#  batch_normalization_94 (Ba  (None, 14, 14, 256)          1024      ['conv2d_94[0][0]']
#  tchNormalization)
#
#  re_lu_87 (ReLU)             (None, 14, 14, 256)          0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_95 (Conv2D)          (None, 14, 14, 1024)         263168    ['re_lu_87[0][0]']
#
#  batch_normalization_95 (Ba  (None, 14, 14, 1024)         4096      ['conv2d_95[0][0]']
#  tchNormalization)
#
#  add_28 (Add)                (None, 14, 14, 1024)         0         ['batch_normalization_95[0][0]
#                                                                     ',
#                                                                      're_lu_85[0][0]']
#
#  re_lu_88 (ReLU)             (None, 14, 14, 1024)         0         ['add_28[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 14, 14, 512)          524800    ['re_lu_88[0][0]']
#
#  batch_normalization_96 (Ba  (None, 14, 14, 512)          2048      ['conv2d_96[0][0]']
#  tchNormalization)
#
#  re_lu_89 (ReLU)             (None, 14, 14, 512)          0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  conv2d_97 (Conv2D)          (None, 7, 7, 512)            2359808   ['re_lu_89[0][0]']
#
#  batch_normalization_97 (Ba  (None, 7, 7, 512)            2048      ['conv2d_97[0][0]']
#  tchNormalization)
#
#  re_lu_90 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  conv2d_98 (Conv2D)          (None, 7, 7, 2048)           1050624   ['re_lu_90[0][0]']
#
#  conv2d_99 (Conv2D)          (None, 7, 7, 2048)           2099200   ['re_lu_88[0][0]']
#
#  batch_normalization_98 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_98[0][0]']
#  tchNormalization)
#
#  batch_normalization_99 (Ba  (None, 7, 7, 2048)           8192      ['conv2d_99[0][0]']
#  tchNormalization)
#
#  add_29 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_98[0][0]
#                                                                     ',
#                                                                      'batch_normalization_99[0][0]
#                                                                     ']
#
#  re_lu_91 (ReLU)             (None, 7, 7, 2048)           0         ['add_29[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 7, 7, 512)            1049088   ['re_lu_91[0][0]']
#
#  batch_normalization_100 (B  (None, 7, 7, 512)            2048      ['conv2d_100[0][0]']
#  atchNormalization)
#
#  re_lu_92 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  conv2d_101 (Conv2D)         (None, 7, 7, 512)            2359808   ['re_lu_92[0][0]']
#
#  batch_normalization_101 (B  (None, 7, 7, 512)            2048      ['conv2d_101[0][0]']
#  atchNormalization)
#
#  re_lu_93 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_101[0][0
#                                                                     ]']
#
#  conv2d_102 (Conv2D)         (None, 7, 7, 2048)           1050624   ['re_lu_93[0][0]']
#
#  batch_normalization_102 (B  (None, 7, 7, 2048)           8192      ['conv2d_102[0][0]']
#  atchNormalization)
#
#  add_30 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_102[0][0
#                                                                     ]',
#                                                                      're_lu_91[0][0]']
#
#  re_lu_94 (ReLU)             (None, 7, 7, 2048)           0         ['add_30[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 7, 7, 512)            1049088   ['re_lu_94[0][0]']
#
#  batch_normalization_103 (B  (None, 7, 7, 512)            2048      ['conv2d_103[0][0]']
#  atchNormalization)
#
#  re_lu_95 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 7, 7, 512)            2359808   ['re_lu_95[0][0]']
#
#  batch_normalization_104 (B  (None, 7, 7, 512)            2048      ['conv2d_104[0][0]']
#  atchNormalization)
#
#  re_lu_96 (ReLU)             (None, 7, 7, 512)            0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  conv2d_105 (Conv2D)         (None, 7, 7, 2048)           1050624   ['re_lu_96[0][0]']
#
#  batch_normalization_105 (B  (None, 7, 7, 2048)           8192      ['conv2d_105[0][0]']
#  atchNormalization)
#
#  add_31 (Add)                (None, 7, 7, 2048)           0         ['batch_normalization_105[0][0
#                                                                     ]',
#                                                                      're_lu_94[0][0]']
#
#  re_lu_97 (ReLU)             (None, 7, 7, 2048)           0         ['add_31[0][0]']
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['re_lu_97[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 2)                    4098      ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 23591810 (90.00 MB)
# Trainable params: 23538690 (89.79 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy

# Learning rate is also a hyperparameter
model.compile(loss=BinaryCrossentropy(),
              optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping

import tensorflow as tf

# %%
# Resize the training and validation data
train_x_resized = tf.image.resize(train_x, size=(224, 224))
valid_x_resized = tf.image.resize(valid_x, size=(224, 224))

# %%
import tensorflow as tf

# Convert labels to one-hot encoded format
train_y_one_hot = tf.keras.utils.to_categorical(train_y, num_classes=n_classes)
valid_y_one_hot = tf.keras.utils.to_categorical(valid_y, num_classes=n_classes)

# Define the early stopping callback


# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with the one-hot encoded labels
history =model.fit(
    train_x_resized,
    train_y_one_hot,
    epochs=16,
    validation_data=(valid_x_resized, valid_y_one_hot)
)

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
loss =history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
acc = history.history['accuracy']
val_acc =history.history['val_accuracy']

# %%
plt.plot(epochs, acc, 'g', label = 'Training accuracy')
plt.plot(epochs, val_acc,'r', label = "Validation accuracy")
plt.plot(epochs, loss, 'b', label = 'Training loss')
plt.plot(epochs, val_loss, 'y', label = "Validation loss")
plt.title(" Training and validation metric evolution")
plt.xlabel("Epochs")
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.show()

# %%
# Evaluate model on validation data
eval_results = model.evaluate(valid_x_resized, valid_y_one_hot)

# Make predictions on validation data
predictions = model.predict(valid_x_resized)
predicted_classes = np.argmax(predictions, axis=1)

# Calculate metrics
num_correct = np.sum(predicted_classes == np.argmax(valid_y_one_hot, axis=1))
accuracy = num_correct / valid_y_one_hot.shape[0]

true_positives = np.sum(np.logical_and(predicted_classes==1,
                                        np.argmax(valid_y_one_hot, axis=1)==1))
false_positives = np.sum(np.logical_and(predicted_classes==1,
                                        np.argmax(valid_y_one_hot, axis=1)!=1))
false_negatives = np.sum(np.logical_and(predicted_classes!=1,
                                        np.argmax(valid_y_one_hot, axis=1)==1))

precision = true_positives / (true_positives + false_positives)
recall = true_positives / (true_positives + false_negatives)
f1 = 2 * (precision * recall) / (precision + recall)

# Print results
print("Accuracy: {:.4f}".format(accuracy))
print("Precision: {:.4f}".format(precision))
print("Recall: {:.4f}".format(recall))
print("F1 Score: {:.4f}".format(f1))
# Out:
# 11/11 [==============================] - 79s 7s/step - loss: 0.3164 - accuracy: 0.9086
# 11/11 [==============================] - 74s 7s/step
# Accuracy: 0.9086
# Precision: 0.9132
# Recall: 0.9861
# F1 Score: 0.9482

# %%
model.save('Resnet.h1')
